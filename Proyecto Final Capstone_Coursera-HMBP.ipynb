# %% [markdown]
# # PROYECTO FINAL CAPSTONE_COURSERA-HMBP

# %% [markdown]
# Este notebook se utilizará principalmente para cargar tareas y compartir en el curso en el marco del Proyecto final Capstone_Cousera del curso de Ciencia de datos de IBM - Coursera.

# %% [markdown]
# Fecha de Inicio: 26-10-2021

# %%
import pandas as pd

# %%
import numpy as np

# %%
print('¡Hola, Proyecto Final del Curso!')
# Out:
# ¡Hola, Proyecto Final del Curso!
